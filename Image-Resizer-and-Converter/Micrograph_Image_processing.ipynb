# %%
from skimage import io
import os
from matplotlib import pyplot as plt
import numpy as np
from skimage.transform import rescale, resize, downscale_local_mean
from tkinter import *
from tkinter import filedialog
from tkinter.filedialog import askopenfilename

def resizer():
    Length = int(Image_Length.get())
    Breadth = int(Image_Breadth.get())
    new_size = (Length,Breadth)
    file_format = str(Output_fformat.get())
    selected = Typechoice.get()
    
    if Length =="" or Breadth =="" or file_format=="":
        result.delete(0.0,END)
        result.insert(END,"\n Enter all inputs")
    
    img = io.imread(file_path, as_gray=selected)
    
    folder = out_path + "/"
    file_name = str(Output_fname.get())
    fname = folder + file_name + "." + file_format
    
    resized_img = resize(img, new_size)
    plt.axis('off')
    save = io.imsave(fname, resized_img)
    
    result.delete(0.0,END)
    result.insert(END,"\n Successful...")
    
    return

def format_converter():
    file_format = str(Output_fformat.get())
    selected = Typechoice.get()
    
    if file_format =="":
        result.delete(0.0,END)
        result.insert(END,"\n Enter paths and format")
    
    img = io.imread(file_path, as_gray=selected)
    
    folder = out_path + "/"
    file_name = str(Output_fname.get())
    fname = folder + file_name +  "." + file_format
    
    plt.axis('off')
    save = io.imsave(fname, img)
    
    result.delete(0.0,END)
    result.insert(END,"\n Successful...")
    
    return

    
window = Tk()
window.geometry("400x500") #the size of the window
window.title("Image-Proc | © Bamidele 2021")
window.iconbitmap(r"/Users/emmanuel_bamidele/Desktop/Bamspace/Data_Science_Tutorial/Python projects/Image_Processing/img-icon.ico")

Programname = Label(window, font=('Verdana',25,'bold'), text="IMAGE-PROC", fg="blue")

Programname.grid(row=1, column=6, padx=90, pady=30) 

Choosepath = Label(window, font=('Verdana',14,'italic'), text="Choose image path and output folder", fg="red")
Choosepath.place(relx=.08, rely=.18)  #second method of placing

file_path = askopenfilename()

out_path =filedialog.askdirectory()

EnterDetails = Label(window, font=('Verdana',14,'italic'), text="Please enter the following inputs", fg="blue")
EnterDetails.place(relx=.08, rely=.24) 

Length = Label(window, text="Image Length", font=('Copperplate Gothic',15, 'bold'))
Length.place(relx=.02, rely=.32)

Image_Length = Entry(window)
Image_Length.place(relx=.37, rely=.32)

Breadth = Label(window, text="Image Breadth", font=('Copperplate Gothic',15, 'bold'))
Breadth.place(relx=.02, rely=.40)

Image_Breadth = Entry(window)
Image_Breadth.place(relx=.37, rely=.40)

Output_name = Label(window, text="Output File Name", font=('Copperplate Gothic',15, 'bold'))
Output_name.place(relx=.02, rely=.48)

Output_fname = Entry(window)
Output_fname.place(relx=.37, rely=.48)

Output_format = Label(window, text="Output Format", font=('Copperplate Gothic',15, 'bold'))
Output_format.place(relx=.02, rely=.56)

Output_fformat = Entry(window)
Output_fformat.place(relx=.37, rely=.56)

Typechoice = BooleanVar()
Choice = Radiobutton(window, text= "Color", variable=Typechoice, value=False)
Choice.place(relx=.23, rely=.64)      
    
Choice = Radiobutton(window, text= "Grayscale", variable=Typechoice, value=True)
Choice.place(relx=.45, rely=.64) 


Resize = Button(window, text="Resize & Download", command=resizer)
Resize.place(relx=.05, rely=.74)

Convert = Button(window, text="Convert & Download", command=format_converter)
Convert.place(relx=.45, rely=.74)

result = Text(window, height=4, width=50, wrap=WORD)
result.place(relx=.03, rely=.82)

window.mainloop()
# Out:
# 2021-12-08 22:38:33.462 python[34350:1871687] *** Assertion failure in -[NSOpenPanel beginServicePanel:asyncExHandler:], NSVBOpenAndSavePanels.m:1907
# 2021-12-08 22:38:33.469 python[34350:1871687] -[NSSavePanel beginWithCompletionHandler:]_block_invoke caught non-fatal NSInternalInconsistencyException '<NSOpenPanel: 0x7f7f28f54d30> is attempting to advance this Open/Save panel to run phase while another self.advanceToRunPhaseCompletionHandler is in waiting for a previous attempt. An Open/Save panel cannot start to advance more than once.' with user dictionary {
#     NSAssertFile = "NSVBOpenAndSavePanels.m";
#     NSAssertLine = 1907;
# } and backtrace (
# 	0   CoreFoundation                      0x00007ff81631fe5b __exceptionPreprocess + 242
# 	1   libobjc.A.dylib                     0x00007ff816080b9d objc_exception_throw + 48
# 	2   Foundation                          0x00007ff8171d6653 -[NSAssertionHandler handleFailureInMethod:object:file:lineNumber:description:] + 267
# 	3   AppKit                              0x00007ff8196d9269 -[NSSavePanel beginServicePanel:asyncExHandler:] + 475
# 	4   AppKit                              0x00007ff8196da51d -[NSSavePanel runModal] + 297
# 	5   libtk8.6.dylib                      0x00000001138d5003 showOpenSavePanel + 195
# 	6   libtk8.6.dylib                      0x00000001138d467d Tk_GetOpenFileObjCmd + 2205
# 	7   libtcl8.6.dylib                     0x00000001135050d2 Tcl_EvalObjv + 370
# 	8   _tkinter.cpython-38-darwin.so       0x000000010f36d19b Tkapp_Call + 203
# 	9   python3.8                           0x000000010bf31ee8 cfunction_call_varargs + 216
# 	10  python3.8                           0x000000010c07aa92 _PyEval_EvalFrameDefault + 49330
# 	11  python3.8                           0x000000010c06cdc4 _PyEval_EvalCodeWithName + 564
# 	12  python3.8                           0x000000010bf328ca _PyFunction_Vectorcall + 426
# 	13  python3.8                           0x000000010c07ce32 call_function + 162
# 	14  python3.8                           0x000000010c079353 _PyEval_EvalFrameDefault + 43379
# 	15  python3.8                           0x000000010c06cdc4 _PyEval_EvalCodeWithName + 564
# 	16  python3.8                           0x000000010bf328ca _PyFunction_Vectorcall + 426
# 	17  python3.8                           0x000000010c07ce32 call_function + 162
# 	18  python3.8                           0x000000010c07a7e7 _PyEval_EvalFrameDefault + 48647
# 	19  python3.8                           0x000000010c06cdc4 _PyEval_EvalCodeWithName + 564
# 	20  python3.8                           0x000000010c067839 builtin_exec + 361
# 	21  python3.8                           0x000000010bf90104 cfunction_vectorcall_FASTCALL + 84
# 	22  python3.8                           0x000000010c07ce32 call_function + 162
# 	23  python3.8                           0x000000010c07a7e7 _PyEval_EvalFrameDefault + 48647
# 	24  python3.8                           0x000000010bf4aff8 gen_send_ex + 168
# 	25  python3.8                           0x000000010c074449 _PyEval_EvalFrameDefault + 23145
# 	26  python3.8                           0x000000010bf4aff8 gen_send_ex + 168
# 	27  python3.8                           0x000000010c074449 _PyEval_EvalFrameDefault + 23145
# 	28  python3.8                           0x000000010bf4aff8 gen_send_ex + 168
# 	29  python3.8                           0x000000010bf40e4a method_vectorcall_O + 138
# 	30  python3.8                           0x000000010c07ce32 call_function + 162
# 	31  python3.8                           0x000000010c079353 _PyEval_EvalFrameDefault + 43379
# 	32  python3.8                           0x000000010bf32818 _PyFunction_Vectorcall + 248
# 	33  python3.8                           0x000000010c07ce32 call_function + 162
# 	34  python3.8                           0x000000010c07a7e7 _PyEval_EvalFrameDefault + 48647
# 	35  python3.8                           0x000000010bf32818 _PyFunction_Vectorcall + 248
# 	36  python3.8                           0x000000010c07ce32 call_function + 162
# 	37  python3.8                           0x000000010c079353 _PyEval_EvalFrameDefault + 43379
# 	38  python3.8                           0x000000010c06cdc4 _PyEval_EvalCodeWithName + 564
# 	39  python3.8                           0x000000010bf328ca _PyFunction_Vectorcall + 426
# 	40  python3.8                           0x000000010bf3640d method_vectorcall + 349
# 	41  python3.8                           0x000000010bf31a69 PyVectorcall_Call + 121
# 	42  python3.8                           0x000000010c07a994 _PyEval_EvalFrameDefault + 49076
# 	43  python3.8                           0x000000010c06cdc4 _PyEval_EvalCodeWithName + 564
# 	44  python3.8                           0x000000010bf328ca _PyFunction_Vectorcall + 426
# 	45  python3.8                           0x000000010bf3633d method_vectorcall + 141
# 	46  python3.8                           0x000000010c07ce32 call_function + 162
# 	47  python3.8                           0x000000010c07a88d _PyEval_EvalFrameDefault + 48813
# 	48  python3.8                           0x000000010bf4aff8 gen_send_ex + 168
# 	49  python3.8                           0x000000010c074449 _PyEval_EvalFrameDefault + 23145
# 	50  python3.8                           0x000000010bf4aff8 gen_send_ex + 168
# 	51  python3.8                           0x000000010c074449 _PyEval_EvalFrameDefault + 23145
# 	52  python3.8                           0x000000010bf4aff8 gen_send_ex + 168
# 	53  python3.8                           0x000000010c074449 _PyEval_EvalFrameDefault + 23145
# 	54  python3.8                           0x000000010bf4aff8 gen_send_ex + 168
# 	55  python3.8                           0x000000010c074449 _PyEval_EvalFrameDefault + 23145
# 	56  python3.8                           0x000000010bf4aff8 gen_send_ex + 168
# 	57  _asyncio.cpython-38-darwin.so       0x000000010c822d4b task_step + 171
# 	58  _asyncio.cpython-38-darwin.so       0x000000010c822ad8 TaskWakeupMethWrapper_call + 152
# 	59  python3.8                           0x000000010bf3121d _PyObject_MakeTpCall + 173
# 	60  python3.8                           0x000000010c0ac4d2 context_run + 210
# 	61  python3.8                           0x000000010bf9024c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 	62  python3.8                           0x000000010bf31a69 PyVectorcall_Call + 121
# 	63  python3.8                           0x000000010c07ab4d _PyEval_EvalFrameDefault + 49517
# 	64  python3.8                           0x000000010bf32818 _PyFunction_Vectorcall + 248
# 	65  python3.8                           0x000000010c07ce32 call_function + 162
# 	66  python3.8                           0x000000010c079353 _PyEval_EvalFrameDefault + 43379
# 	67  python3.8                           0x000000010bf32818 _PyFunction_Vectorcall + 248
# 	68  python3.8                           0x000000010c07ce32 call_function + 162
# 	69  python3.8                           0x000000010c079353 _PyEval_EvalFrameDefault + 43379
# 	70  python3.8                           0x000000010bf32818 _PyFunction_Vectorcall + 248
# 	71  python3.8                           0x000000010c07ce32 call_function + 162
# 	72  python3.8                           0x000000010c079353 _PyEval_EvalFrameDefault + 43379
# 	73  python3.8                           0x000000010bf32818 _PyFunction_Vectorcall + 248
# 	74  python3.8                           0x000000010c07ce32 call_function + 162
# 	75  python3.8                           0x000000010c079353 _PyEval_EvalFrameDefault + 43379
# 	76  python3.8                           0x000000010bf32818 _PyFunction_Vectorcall + 248
# 	77  python3.8                           0x000000010c07ce32 call_function + 162
# 	78  python3.8                           0x000000010c079353 _PyEval_EvalFrameDefault + 43379
# 	79  python3.8                           0x000000010c06cdc4 _PyEval_EvalCodeWithName + 564
# 	80  python3.8                           0x000000010bf328ca _PyFunction_Vectorcall + 426
# 	81  python3.8                           0x000000010bf3633d method_vectorcall + 141
# 	82  python3.8                           0x000000010c07ce32 call_function + 162
# 	83  python3.8                           0x000000010c0793e2 _PyEval_EvalFrameDefault + 43522
# 	84  python3.8                           0x000000010c06cdc4 _PyEval_EvalCodeWithName + 564
# 	85  python3.8                           0x000000010c067839 builtin_exec + 361
# 	86  python3.8                           0x000000010bf90104 cfunction_vectorcall_FASTCALL + 84
# 	87  python3.8                           0x000000010c07ce32 call_function + 162
# 	88  python3.8                           0x000000010c07a7e7 _PyEval_EvalFrameDefault + 48647
# 	89  python3.8                           0x000000010c06cdc4 _PyEval_EvalCodeWithName + 564
# 	90  python3.8                           0x000000010bf328ca _PyFunction_Vectorcall + 426
# 	91  python3.8                           0x000000010c07ce32 call_function + 162
# 	92  python3.8                           0x000000010c07a7e7 _PyEval_EvalFrameDefault + 48647
# 	93  python3.8                           0x000000010c06cdc4 _PyEval_EvalCodeWithName + 564
# 	94  python3.8                           0x000000010bf328ca _PyFunction_Vectorcall + 426
# 	95  python3.8                           0x000000010bf31a69 PyVectorcall_Call + 121
# 	96  python3.8                           0x000000010c11cefb pymain_run_module + 235
# 	97  python3.8                           0x000000010c11c781 pymain_run_python + 289
# 	98  python3.8                           0x000000010c11c605 Py_RunMain + 37
# 	99  python3.8                           0x000000010c11de21 pymain_main + 49
# 	100 python3.8                           0x000000010bf04678 main + 56
# 	101 dyld                                0x000000011463a4fe start + 462
# )
# 2021-12-08 22:38:33.533 python[34350:1871687] Warning: Expected min height of view: (<NSButton: 0x7f7f19072c00>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2021-12-08 22:38:35.172 python[34350:1871687] Warning: Expected min height of view: (<NSButton: 0x7f7f8a0ca1f0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2021-12-08 22:38:35.358 python[34350:1871687] *** Assertion failure in -[NSOpenPanel beginServicePanel:asyncExHandler:], NSVBOpenAndSavePanels.m:1907
# 2021-12-08 22:38:35.363 python[34350:1871687] -[NSSavePanel beginWithCompletionHandler:]_block_invoke caught non-fatal NSInternalInconsistencyException '<NSOpenPanel: 0x7f7f8a0cc610> is attempting to advance this Open/Save panel to run phase while another self.advanceToRunPhaseCompletionHandler is in waiting for a previous attempt. An Open/Save panel cannot start to advance more than once.' with user dictionary {
#     NSAssertFile = "NSVBOpenAndSavePanels.m";
#     NSAssertLine = 1907;
# } and backtrace (
# 	0   CoreFoundation                      0x00007ff81631fe5b __exceptionPreprocess + 242
# 	1   libobjc.A.dylib                     0x00007ff816080b9d objc_exception_throw + 48
# 	2   Foundation                          0x00007ff8171d6653 -[NSAssertionHandler handleFailureInMethod:object:file:lineNumber:description:] + 267
# 	3   AppKit                              0x00007ff8196d9269 -[NSSavePanel beginServicePanel:asyncExHandler:] + 475
# 	4   AppKit                              0x00007ff8196da51d -[NSSavePanel runModal] + 297
# 	5   libtk8.6.dylib                      0x00000001138d5003 showOpenSavePanel + 195
# 	6   libtk8.6.dylib                      0x00000001138d60df Tk_ChooseDirectoryObjCmd + 1151
# 	7   libtcl8.6.dylib                     0x00000001135050d2 Tcl_EvalObjv + 370
# 	8   _tkinter.cpython-38-darwin.so       0x000000010f36d19b Tkapp_Call + 203
# 	9   python3.8                           0x000000010bf31ee8 cfunction_call_varargs + 216
# 	10  python3.8                           0x000000010c07aa92 _PyEval_EvalFrameDefault + 49330
# 	11  python3.8                           0x000000010c06cdc4 _PyEval_EvalCodeWithName + 564
# 	12  python3.8                           0x000000010bf328ca _PyFunction_Vectorcall + 426
# 	13  python3.8                           0x000000010c07ce32 call_function + 162
# 	14  python3.8                           0x000000010c079353 _PyEval_EvalFrameDefault + 43379
# 	15  python3.8                           0x000000010c06cdc4 _PyEval_EvalCodeWithName + 564
# 	16  python3.8                           0x000000010bf328ca _PyFunction_Vectorcall + 426
# 	17  python3.8                           0x000000010c07ce32 call_function + 162
# 	18  python3.8                           0x000000010c0793e2 _PyEval_EvalFrameDefault + 43522
# 	19  python3.8                           0x000000010c06cdc4 _PyEval_EvalCodeWithName + 564
# 	20  python3.8                           0x000000010c067839 builtin_exec + 361
# 	21  python3.8                           0x000000010bf90104 cfunction_vectorcall_FASTCALL + 84
# 	22  python3.8                           0x000000010c07ce32 call_function + 162
# 	23  python3.8                           0x000000010c07a7e7 _PyEval_EvalFrameDefault + 48647
# 	24  python3.8                           0x000000010bf4aff8 gen_send_ex + 168
# 	25  python3.8                           0x000000010c074449 _PyEval_EvalFrameDefault + 23145
# 	26  python3.8                           0x000000010bf4aff8 gen_send_ex + 168
# 	27  python3.8                           0x000000010c074449 _PyEval_EvalFrameDefault + 23145
# 	28  python3.8                           0x000000010bf4aff8 gen_send_ex + 168
# 	29  python3.8                           0x000000010bf40e4a method_vectorcall_O + 138
# 	30  python3.8                           0x000000010c07ce32 call_function + 162
# 	31  python3.8                           0x000000010c079353 _PyEval_EvalFrameDefault + 43379
# 	32  python3.8                           0x000000010bf32818 _PyFunction_Vectorcall + 248
# 	33  python3.8                           0x000000010c07ce32 call_function + 162
# 	34  python3.8                           0x000000010c07a7e7 _PyEval_EvalFrameDefault + 48647
# 	35  python3.8                           0x000000010bf32818 _PyFunction_Vectorcall + 248
# 	36  python3.8                           0x000000010c07ce32 call_function + 162
# 	37  python3.8                           0x000000010c079353 _PyEval_EvalFrameDefault + 43379
# 	38  python3.8                           0x000000010c06cdc4 _PyEval_EvalCodeWithName + 564
# 	39  python3.8                           0x000000010bf328ca _PyFunction_Vectorcall + 426
# 	40  python3.8                           0x000000010bf3640d method_vectorcall + 349
# 	41  python3.8                           0x000000010bf31a69 PyVectorcall_Call + 121
# 	42  python3.8                           0x000000010c07a994 _PyEval_EvalFrameDefault + 49076
# 	43  python3.8                           0x000000010c06cdc4 _PyEval_EvalCodeWithName + 564
# 	44  python3.8                           0x000000010bf328ca _PyFunction_Vectorcall + 426
# 	45  python3.8                           0x000000010bf3633d method_vectorcall + 141
# 	46  python3.8                           0x000000010c07ce32 call_function + 162
# 	47  python3.8                           0x000000010c07a88d _PyEval_EvalFrameDefault + 48813
# 	48  python3.8                           0x000000010bf4aff8 gen_send_ex + 168
# 	49  python3.8                           0x000000010c074449 _PyEval_EvalFrameDefault + 23145
# 	50  python3.8                           0x000000010bf4aff8 gen_send_ex + 168
# 	51  python3.8                           0x000000010c074449 _PyEval_EvalFrameDefault + 23145
# 	52  python3.8                           0x000000010bf4aff8 gen_send_ex + 168
# 	53  python3.8                           0x000000010c074449 _PyEval_EvalFrameDefault + 23145
# 	54  python3.8                           0x000000010bf4aff8 gen_send_ex + 168
# 	55  python3.8                           0x000000010c074449 _PyEval_EvalFrameDefault + 23145
# 	56  python3.8                           0x000000010bf4aff8 gen_send_ex + 168
# 	57  _asyncio.cpython-38-darwin.so       0x000000010c822d4b task_step + 171
# 	58  _asyncio.cpython-38-darwin.so       0x000000010c822ad8 TaskWakeupMethWrapper_call + 152
# 	59  python3.8                           0x000000010bf3121d _PyObject_MakeTpCall + 173
# 	60  python3.8                           0x000000010c0ac4d2 context_run + 210
# 	61  python3.8                           0x000000010bf9024c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 	62  python3.8                           0x000000010bf31a69 PyVectorcall_Call + 121
# 	63  python3.8                           0x000000010c07ab4d _PyEval_EvalFrameDefault + 49517
# 	64  python3.8                           0x000000010bf32818 _PyFunction_Vectorcall + 248
# 	65  python3.8                           0x000000010c07ce32 call_function + 162
# 	66  python3.8                           0x000000010c079353 _PyEval_EvalFrameDefault + 43379
# 	67  python3.8                           0x000000010bf32818 _PyFunction_Vectorcall + 248
# 	68  python3.8                           0x000000010c07ce32 call_function + 162
# 	69  python3.8                           0x000000010c079353 _PyEval_EvalFrameDefault + 43379
# 	70  python3.8                           0x000000010bf32818 _PyFunction_Vectorcall + 248
# 	71  python3.8                           0x000000010c07ce32 call_function + 162
# 	72  python3.8                           0x000000010c079353 _PyEval_EvalFrameDefault + 43379
# 	73  python3.8                           0x000000010bf32818 _PyFunction_Vectorcall + 248
# 	74  python3.8                           0x000000010c07ce32 call_function + 162
# 	75  python3.8                           0x000000010c079353 _PyEval_EvalFrameDefault + 43379
# 	76  python3.8                           0x000000010bf32818 _PyFunction_Vectorcall + 248
# 	77  python3.8                           0x000000010c07ce32 call_function + 162
# 	78  python3.8                           0x000000010c079353 _PyEval_EvalFrameDefault + 43379
# 	79  python3.8                           0x000000010c06cdc4 _PyEval_EvalCodeWithName + 564
# 	80  python3.8                           0x000000010bf328ca _PyFunction_Vectorcall + 426
# 	81  python3.8                           0x000000010bf3633d method_vectorcall + 141
# 	82  python3.8                           0x000000010c07ce32 call_function + 162
# 	83  python3.8                           0x000000010c0793e2 _PyEval_EvalFrameDefault + 43522
# 	84  python3.8                           0x000000010c06cdc4 _PyEval_EvalCodeWithName + 564
# 	85  python3.8                           0x000000010c067839 builtin_exec + 361
# 	86  python3.8                           0x000000010bf90104 cfunction_vectorcall_FASTCALL + 84
# 	87  python3.8                           0x000000010c07ce32 call_function + 162
# 	88  python3.8                           0x000000010c07a7e7 _PyEval_EvalFrameDefault + 48647
# 	89  python3.8                           0x000000010c06cdc4 _PyEval_EvalCodeWithName + 564
# 	90  python3.8                           0x000000010bf328ca _PyFunction_Vectorcall + 426
# 	91  python3.8                           0x000000010c07ce32 call_function + 162
# 	92  python3.8                           0x000000010c07a7e7 _PyEval_EvalFrameDefault + 48647
# 	93  python3.8                           0x000000010c06cdc4 _PyEval_EvalCodeWithName + 564
# 	94  python3.8                           0x000000010bf328ca _PyFunction_Vectorcall + 426
# 	95  python3.8                           0x000000010bf31a69 PyVectorcall_Call + 121
# 	96  python3.8                           0x000000010c11cefb pymain_run_module + 235
# 	97  python3.8                           0x000000010c11c781 pymain_run_python + 289
# 	98  python3.8                           0x000000010c11c605 Py_RunMain + 37
# 	99  python3.8                           0x000000010c11de21 pymain_main + 49
# 	100 python3.8                           0x000000010bf04678 main + 56
# 	101 dyld                                0x000000011463a4fe start + 462
# )
# 2021-12-08 22:38:35.389 python[34350:1871687] Warning: Expected min height of view: (<NSButton: 0x7f7f28f4e770>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
# 2021-12-08 22:38:36.814 python[34350:1871687] Warning: Expected min height of view: (<NSButton: 0x7f7f1908cae0>) to be less than or equal to 30 but got a height of 32.000000. This error will be logged once per view in violation.
